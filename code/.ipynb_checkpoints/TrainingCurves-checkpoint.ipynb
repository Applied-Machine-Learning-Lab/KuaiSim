# %%
# %matplotlib inline
from plot_utils import smooth, get_online_training_info, multiplot_multiple_line
import numpy as np

smoothness = 1
expe = "ddpg_OneStageHyperPolicy_with_DotScore_actor0.00003_critic0.0001_niter20000_reg0.00001_ep0.01_noise0.1_bs128_epbs32_step20_seed11"
log_path = "output/Kuairand_Pure/agents/" + expe  + "/model.report"
info = get_online_training_info(log_path)

for k in list(info.keys()):
    v = info[k]
    info[k] = smooth(np.array(v), smoothness)
print('\t'.join([k for k,v in info.items()]))
print('\t'.join([str(v[-1]) for k,v in info.items()]))
multiplot_multiple_line(["curve"], [info], x_name = 'episode')
# Out:
# 264it [00:00, 13041.44it/s]
# episode	step	leave	temper	coverage	ILD	actor_loss	critic_loss	Q	next_Q	avg_reward	reward_variance	avg_total_reward	max_total_reward	min_total_reward	is_click_rate	long_view_rate	is_like_rate	is_comment_rate	is_forward_rate	is_follow_rate	is_hate_rate
# 2595.0	7.1	4.6	8.333333730697632	49.4	0.9874406132381409	-0.7839118897914887	0.10329259559512138	0.7015574783086777	0.7842771679162979	0.5486979335546494	0.045591121166944505	3.895873248577118	4.8166668891906745	3.116666781902313	0.5486979365348816	0.5513021022081375	0.5882812649011612	0.5960937678813933	0.5635416805744171	0.5643229395151138	0.7260416865348815

# %%
# %matplotlib inline
from plot_utils import smooth, get_online_training_info, multiplot_multiple_line
import numpy as np

smoothness = 10
param_list = ['0.00001', '0.00003', '0.0001', '0.0003']
param_key = 'LR_'

stats = []
for param in param_list:
    expe = f"ddpg_OneStageHyperPolicy_with_DotScore_actor{param}_critic0.001_niter20000_reg0.00001_ep0.01_noise0.1_bs128_epbs32_step20_seed11"
    log_path = "output/Kuairand_Pure/agents/" + expe  + "/model.report"
    info = get_online_training_info(log_path)

    for k in list(info.keys()):
        v = info[k]
        info[k] = smooth(np.array(v), smoothness)
    print('\t'.join([k for k,v in info.items()]))
    print('\t'.join([str(v[-1]) for k,v in info.items()]))
    stats.append(info)
multiplot_multiple_line([param_key + param for param in param_list], stats, x_name = 'episode')
# Out:
# 1999it [00:00, 12795.53it/s]
# episode	step	leave	temper	coverage	ILD	actor_loss	critic_loss	Q	next_Q	avg_reward	reward_variance	avg_total_reward	max_total_reward	min_total_reward	is_click_rate	long_view_rate	is_like_rate	is_comment_rate	is_forward_rate	is_follow_rate	is_hate_rate
# 19940.0	10.867846409090909	2.9545454545454546	9.05909083106301	9.645454545454545	-0.8934893467209555	-0.1719691808928143	0.02047135948457501	0.17053969651460646	0.17193985310467808	0.15350379296155137	0.019649622071830727	1.6655988427725703	2.092424258318814	1.2499999929558145	0.15350379282608625	0.15492424739270724	0.18380682382901964	0.15771780825135384	0.17372159642082724	0.1640151565513489	0.34640152454376216
# 1999it [00:00, 12690.75it/s]
# episode	step	leave	temper	coverage	ILD	actor_loss	critic_loss	Q	next_Q	avg_reward	reward_variance	avg_total_reward	max_total_reward	min_total_reward	is_click_rate	long_view_rate	is_like_rate	is_comment_rate	is_forward_rate	is_follow_rate	is_hate_rate
# 19940.0	11.076579727272728	2.890909090909091	9.130634450912478	10.627272727272727	-0.8008616490797563	-0.2774676428599791	0.03442704652182081	0.25571759085763585	0.2772482281381433	0.19687500600703062	0.02534671391688541	2.1841919541358945	2.7257575988769527	1.6803030268712478	0.19687500492330978	0.19843750541860405	0.19266098936681042	0.17964015621268614	0.18385417172685264	0.184611747820269	0.3683712229640646
# 1999it [00:00, 12673.22it/s]
# episode	step	leave	temper	coverage	ILD	actor_loss	critic_loss	Q	next_Q	avg_reward	reward_variance	avg_total_reward	max_total_reward	min_total_reward	is_click_rate	long_view_rate	is_like_rate	is_comment_rate	is_forward_rate	is_follow_rate	is_hate_rate
# 19940.0	10.0	3.2	9.074621178887107	33.76363636363636	-2.518807612765919	-0.017919871769845486	0.0013685712342108175	0.00958809586326507	0.017904001550579612	0.013304924571209333	0.002074423891132359	0.12792929763143712	0.25454546118324456	0.033333334326744075	0.013304924571209333	0.01354166702790694	0.018134470207786017	0.01420454583977434	0.018797349023886703	0.017045455100014806	0.06463068355382842
# 1908it [00:00, 8425.11it/s]
# episode	step	leave	temper	coverage	ILD	actor_loss	critic_loss	Q	next_Q	avg_reward	reward_variance	avg_total_reward	max_total_reward	min_total_reward	is_click_rate	long_view_rate	is_like_rate	is_comment_rate	is_forward_rate	is_follow_rate	is_hate_rate
# 19030.0	10.0	3.2	9.05809646953236	9.245454545454548	-2.5411818244240503	-0.02345200766893951	0.0007835418423135045	0.006381145665760744	0.023843419289385735	0.00899621228772131	0.0014235094200227073	0.09734848913821308	0.21818182346495715	0.025757576525211337	0.00899621228772131	0.009706439645114272	0.009327651716938072	0.005729166778143156	0.007102272858504544	0.010227272972803224	0.0595643956383521
